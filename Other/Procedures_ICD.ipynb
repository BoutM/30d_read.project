# %% [markdown]
# # ICD Procedures

# %%
import pandas as pd  # type: ignore
import os 
import glob 
from datetime import datetime
import numpy as np
import warnings

# Temporarily suppress FutureWarnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", FutureWarning)

# %%
directory = '/Users/maxb/Library/CloudStorage/OneDrive-UniversityofWaterloo/Hospital Research/Datasets/MIMIC-III_demo'
os.chdir(directory)

picd_df = pd.read_csv("PROCEDURES_ICD.csv")

# %%
picd_df = picd_df.drop('seq_num',axis=1)
picd_df = picd_df.drop('row_id',axis=1)

# %%
picd_df.head()
# Out:
#    subject_id  hadm_id  icd9_code
# 0       10114   167957       3605
# 1       10114   167957       3722
# 2       10114   167957       8856
# 3       10114   167957       9920
# 4       10114   167957       9671

# %%
# picd_df.to_csv('/Users/maxb/Library/CloudStorage/OneDrive-UniversityofWaterloo/Hospital Research/Datasets/Cleaned MIMIC-III Dataset/ICD_PROCEDURES.csv')
