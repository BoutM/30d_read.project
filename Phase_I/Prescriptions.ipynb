# %% [markdown]
# # Prescriptions Table

# %%
import pandas as pd  # type: ignore
import os 
import glob 
from datetime import datetime
import numpy as np

import warnings
# Temporarily suppress FutureWarnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", FutureWarning)

# %%
directory = '/Users/maxb/Library/CloudStorage/OneDrive-UniversityofWaterloo/Hospital Research/Datasets/MIMIC-III_demo'
os.chdir(directory)

pres_df = pd.read_csv("PRESCRIPTIONS.csv")
pres_df.head()

m,n = pres_df.shape

print(m,n)
pres_df.head()
# Out:
# 10398 19
#    row_id  subject_id  hadm_id  icustay_id            startdate  \
# 0   32600       42458   159647         NaN  2146-07-21 00:00:00
# 1   32601       42458   159647         NaN  2146-07-21 00:00:00
# 2   32602       42458   159647         NaN  2146-07-21 00:00:00
# 3   32603       42458   159647         NaN  2146-07-21 00:00:00
# 4   32604       42458   159647         NaN  2146-07-21 00:00:00
#
#                enddate drug_type                         drug  \
# 0  2146-07-22 00:00:00      MAIN  Pneumococcal Vac Polyvalent
# 1  2146-07-22 00:00:00      MAIN                    Bisacodyl
# 2  2146-07-22 00:00:00      MAIN                    Bisacodyl
# 3  2146-07-22 00:00:00      MAIN                        Senna
# 4  2146-07-21 00:00:00      MAIN     Docusate Sodium (Liquid)
#
#                  drug_name_poe            drug_name_generic formulary_drug_cd  \
# 0  Pneumococcal Vac Polyvalent  PNEUMOcoccal Vac Polyvalent           PNEU25I
# ...

# %%
pres_df = pres_df[['subject_id', 'drug', 'dose_val_rx','dose_unit_rx']]

# %% [markdown]
# NOTE: Having issues creating the duration of medication feaature

# %%
# for i in range(m):                                                                 
#    pres_df.loc[i, 'startdate'] = datetime.strptime(pres_df.loc[i, 'startdate'], '%Y-%m-%d %H:%M:%S')
#    pres_df.loc[i, 'enddate'] = datetime.strptime(pres_df.loc[i, 'enddate'], '%Y-%m-%d %H:%M:%S')

# %%
# pres_df['duration'] = pres_df['startdate'] - pres_df['enddate']

# %%
print(pres_df.shape)
pres_df.head()
# Out:
# (10398, 4)
#    subject_id                         drug dose_val_rx dose_unit_rx
# 0       42458  Pneumococcal Vac Polyvalent         0.5           mL
# 1       42458                    Bisacodyl          10           mg
# 2       42458                    Bisacodyl          10           mg
# 3       42458                        Senna           1          TAB
# 4       42458     Docusate Sodium (Liquid)         100           mg

# %%
pres_df.to_csv('/Users/maxb/Library/CloudStorage/OneDrive-UniversityofWaterloo/Hospital Research/Datasets/Cleaned MIMIC-III Dataset/PRESCRIPTIONS.csv')

# %% [markdown]
# # Data Cleaned
