# %% [markdown]
# # Analysis of Cleaned, Subsetted Tables

# %%
import pandas as pd  # type: ignore
import os 
import glob 
from datetime import datetime
import numpy as np
 
import warnings
# Temporarily suppress FutureWarnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore", FutureWarning)

# %%
directory = '/Users/maxb/Library/CloudStorage/OneDrive-UniversityofWaterloo/Hospital Research/Datasets/Cleaned MIMIC-III Dataset'
os.chdir(directory)

# %%
admi_df = pd.read_csv('ADMISSION.csv')
subjects = list(admi_df['subject_id'])
print(len(subjects))
# Out:
# 67

# %%
ICU = pd.read_csv('ICUSTAY.csv')
ICU.loc[(ICU['subject_id'] == 10059), 'los']
# Out:
# 33    1.7806
# Name: los, dtype: float64

# %%
subject_id = subjects[1]
#subject_id = 10059

for i in os.listdir(directory):
    if i.endswith(".csv") and i != ".DS_Store":
        print(str(i)[:-4])
        df = pd.read_csv(i, encoding='utf-8', encoding_errors='ignore')
        df = df[df['subject_id'] == subject_id]
        df = df.drop(columns=df.columns[0], axis = 1)
        print(df.shape)
        display(df.head())
# Out:
# MV_PROCEDURES
# (13, 8)
#     subject_id  hadm_id  icustay_id  itemid  value   cgid  \
# 47       43881   172454      214180  224275   2624  20889
# 48       43881   172454      214180  224277   2624  20889
# 49       43881   172454      214180  225401      1  16934
# 50       43881   172454      214180  225432      1  14419
# 61       43881   167021      243123  224277   1704  20889
#
#    ordercategorydescription         duration
# 47                     Task  1 day, 19:44:00
# 48                     Task  1 day, 19:44:00
# 49             Electrolytes          0:01:00
# 50             Electrolytes          0:01:00
# 61                     Task   1 day, 4:24:00
# ICUSTAY
# (1, 4)
#     subject_id  hadm_id  icustay_id     los
# 65       43881   172454      214180  1.9252
# INPUTEVENTS
# (82, 6)
#      subject_id  hadm_id  icustay_id  itemid  amount amountuom
# 868       43881   172454      214180  225154     1.0        mg
# ...

# %%
df = pd.read_csv('ADMISSION.csv')
a = df[df['subject_id'] == 10006]
